# %%
import plotly.graph_objects as go
from datetime import datetime
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned_stocks/stock_0")
fig = go.Figure(data=[go.Candlestick(x=df['time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
df = pd.read_csv("../data/cleaned_stocks/stock_1")
fig = go.Figure(data=[go.Candlestick(x=df['time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
df = pd.read_csv("../data/cleaned_stocks/stock_2")
fig = go.Figure(data=[go.Candlestick(x=df['time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
df = pd.read_csv("../data/cleaned_stocks/stock_3")
fig = go.Figure(data=[go.Candlestick(x=df['time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
df = pd.read_csv("../data/cleaned_stocks/stock_4")
fig = go.Figure(data=[go.Candlestick(x=df['time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %%
from plotly.subplots import make_subplots
import plotly.express as px

# %%
fig = make_subplots(rows=4, cols=3)
df = pd.read_csv("../data/with_patterns/stock_0")
fig = px.histogram(df,x="Doji",facet_col='DarkCloud',facet_col_wrap=4)
fig.show()
